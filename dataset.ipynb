# %% [markdown]
# <a href="https://colab.research.google.com/github/nzaatta50-collab/Student-Performance-Dataset/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # Load the necessary packages
import pandas as pd
import numpy as np

# %%
mydata=pd.read_csv("myData.csv")

# %%
mydata.tail(5)
# Out:
#      Student_ID  Gender  Age    District School_Type  Study_Hours_per_Week  \
# 995         996    Male   15       Dhaka     Private                    17
# 996         997    Male   16      Sylhet     Private                     9
# 997         998  Female   15      Khulna     Private                     5
# 998         999  Female   17  Chattogram     Private                    28
# 999        1000    Male   15  Mymensingh     Private                    16
#
#      Attendance  Parent_Education  Family_Income_BDT Internet_Access  \
# 995          86  Higher Secondary              11129              No
# 996          77           Primary              38022              No
# 997          82          Graduate              11605              No
# 998          70         Secondary              21970             Yes
# 999          80          Graduate              53705             Yes
#
#     Private_Tuition  Previous_GPA  SSC_Result  HSC_Result
# ...

# %%
mydata.head(10)
# Out:
#    Student_ID  Gender  Age    District School_Type  Study_Hours_per_Week  \
# 0           1    Male   16     Rangpur     Private                    11
# 1           2  Female   17    Rajshahi     Private                     7
# 2           3    Male   15     Barisal     Private                    27
# 3           4    Male   15  Mymensingh     Private                    18
# 4           5    Male   15  Mymensingh      Public                    28
# 5           6  Female   15      Sylhet      Public                    14
# 6           7    Male   18  Mymensingh     Private                    20
# 7           8    Male   15     Rangpur      Public                    20
# 8           9    Male   18      Khulna     Private                    26
# 9          10  Female   18       Dhaka      Public                    14
#
#    Attendance  Parent_Education  Family_Income_BDT Internet_Access  \
# 0          70          Graduate              49169             Yes
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            1000 non-null   int64
#  1   Gender                1000 non-null   object
#  2   Age                   1000 non-null   int64
#  3   District              1000 non-null   object
#  4   School_Type           1000 non-null   object
#  5   Study_Hours_per_Week  1000 non-null   int64
#  6   Attendance            1000 non-null   int64
#  7   Parent_Education      1000 non-null   object
#  8   Family_Income_BDT     1000 non-null   int64
#  9   Internet_Access       1000 non-null   object
#  10  Private_Tuition       1000 non-null   object
#  11  Previous_GPA          1000 non-null   float64
#  12  SSC_Result            1000 non-null   float64
#  13  HSC_Result            1000 non-null   float64
# dtypes: float64(3), int64(5), object(6)
# ...

# %%
mydata.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'District', 'School_Type',
#        'Study_Hours_per_Week', 'Attendance', 'Parent_Education',
#        'Family_Income_BDT', 'Internet_Access', 'Private_Tuition',
#        'Previous_GPA', 'SSC_Result', 'HSC_Result'],
#       dtype='object')

# %%
mydata.describe()
# Out:
#         Student_ID          Age  Study_Hours_per_Week   Attendance  \
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean    500.500000    16.414000             17.102000    79.402000
# std     288.819436     1.095356              7.295809    11.467079
# min       1.000000    15.000000              5.000000    60.000000
# 25%     250.750000    15.000000             11.000000    69.000000
# 50%     500.500000    16.000000             17.000000    79.000000
# 75%     750.250000    17.000000             23.000000    89.000000
# max    1000.000000    18.000000             29.000000    99.000000
#
#        Family_Income_BDT  Previous_GPA   SSC_Result   HSC_Result
# count        1000.000000   1000.000000  1000.000000  1000.000000
# mean        34888.409000      3.994930     4.256920     4.012610
# std         14523.610687      0.585135     0.428974     0.589371
# min         10016.000000      3.000000     3.500000     3.000000
# ...

# %%
import matplotlib.pyplot as plt

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxenplot(x="Gender", y="Age",data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(mydata['SSC_Result'],mydata['Gender'])
# Out:
# Gender      Female  Male
# SSC_Result
# 3.50             1     0
# 3.51             4     7
# 3.52             4     5
# 3.53             5     3
# 3.54             3     3
# ...            ...   ...
# 4.96             4     3
# 4.97             1     2
# 4.98             2     1
# 4.99             3     3
# 5.00             3     1
#
# [151 rows x 2 columns]

# %%
sns.countplot(x="SSC_Result",hue="Gender",data=mydata)
# Out:
# <Axes: xlabel='SSC_Result', ylabel='count'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# random numbers
data = np.random.randn(7500)

# mean and std
m = data.mean()
s = data.std()

# graph
plt.hist(data)

plt.axvline(m, label="Mean")
plt.axvline(m + 2*s, linestyle="--", label="+2 Std")
plt.axvline(m - 2*s, linestyle="--", label="-2 Std")

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.exponential(scale=1, size=7500)


m = data.mean()
s = data.std()


plt.figure(figsize=(6,6))


plt.hist(data, bins=50)


plt.axvline(m, color="black", label="Mean")


plt.axvline(m - 2*s, color="red", linestyle="--", label="-2 Std")


plt.axvline(m + 2*s, color="green", linestyle="--", label="+2 Std")

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = -np.random.exponential(scale=1, size=7500)


m = data.mean()
s = data.std()


plt.figure(figsize=(6,6))


plt.hist(data, bins=50)


plt.axvline(m, color="black", label="Mean")


plt.axvline(m - 2*s, color="red", linestyle="--", label="-2 Std")


plt.axvline(m + 2*s, color="green", linestyle="--", label="+2 Std")

plt.legend()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# Generate normal distribution data
x = np.random.normal(size=10000)

# Style
sns.set_style('ticks')

# Plot original distribution
sns.displot(x, kde=True)

# Mean and standard deviation
print("Mean:", x.mean())
print("Std:", x.std())

# Random sample of 10 values
x_sample = np.random.choice(x, size=10, replace=False)

print("Sample:", x_sample)
print("Sample Mean:", x_sample.mean())


# Function to calculate sample means
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []

    for i in range(n_samples):
        sample = np.random.choice(
            input_dist,
            size=sample_size,
            replace=False
        )

        sample_means.append(sample.mean())

    return sample_means


# Small number of samples
sns.displot(
    sample_mean_calculator(x, 10, 10),
    color='green',
    kde=True
)
plt.xlim(-1.5, 1.5)

# More samples
sns.displot(
    sample_mean_calculator(x, 10, 1000),
    color='green',
    kde=True
)
plt.xlim(-1.5, 1.5)

# Larger sample size
sns.displot(
    sample_mean_calculator(x, 100, 1000),
    color='green',
    kde=True
)
plt.xlim(-1.5, 1.5)

# Even larger sample size
sns.displot(
    sample_mean_calculator(x, 1000, 1000),
    color='green',
    kde=True
)
plt.xlim(-1.5, 1.5)


# Skewed distribution
s = st.skewnorm.rvs(10, size=10000)

# Plot skewed distribution
sns.displot(s, kde=True)

# Distribution of sample means from skewed data
sns.displot(
    sample_mean_calculator(s, 1000, 1000),
    color='green',
    kde=True
)
# Out:
# Mean: -0.010413905639550854
# Std: 1.008508909676632
# Sample: [ 0.57374999 -0.40714865 -0.57376345  1.0566952  -0.44511433 -0.41625246
#  -0.60824338 -1.8112413  -0.81046357  0.01483247]
# Sample Mean: -0.34269494626786

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


m = np.concatenate((
    np.random.normal(loc=0, size=5000),   # mean around 0
    np.random.normal(loc=4, size=5000),   # mean around 4
    np.random.normal(loc=10, size=5000)   # mean around 10
))


sns.displot(m, kde=True)

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x_i = 85
mu = 75
sigma = 10


x = np.random.normal(mu, sigma, 10000)


ax = sns.displot(x, color='gray')

plt.xlim(0, 100)

plt.axvline(mu, color='orange')

for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu + v * sigma, color='olivedrab')

plt.axvline(x_i, color='purple')
plt.axvline(55, color='purple')

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x_i = 75
mu = 60
sigma = 10
x_extra = 55


x = np.random.normal(mu, sigma, 10000)


ax = sns.displot(x, color='gray')


plt.xlim(0, 100)


plt.axvline(mu, color='orange')


for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu + v * sigma, color='olivedrab')


plt.axvline(x_i, color='purple')


plt.axvline(x_extra, color='blue')

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


x_i = 85
mu = 60
sigma = 10


x = np.random.normal(mu, sigma, 10000)


z = (x_i - mu) / sigma
print("Z-score using mu and sigma:", z)


z = (x_i - np.mean(x)) / np.std(x)
print("Z-score using sample mean/std:", z)


count = len(np.where(x > 85)[0])
print("Count greater than 85:", count)


percentage = 100 * count / 10000
print("Percentage greater than 85:", percentage)


p99 = np.percentile(x, 99)
print("99th percentile:", p99)


mu = 90
sigma = 2

print("New mu:", mu)
print("New sigma:", sigma)


y = np.random.normal(mu, sigma, 10000)


sns.displot(y, color='gray')


plt.axvline(mu, color='orange')


for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu + v * sigma, color='olivedrab')


plt.axvline(x_i, color='purple')

plt.show()
# Out:
# Z-score using mu and sigma: 2.5
# Z-score using sample mean/std: 2.5235648436659326
# Count greater than 85: 63
# Percentage greater than 85: 0.63
# 99th percentile: 83.49466341236658
# New mu: 90
# New sigma: 2

# %%
import numpy as np


x_i = 77
mu = 70
sigma = 3


x = np.random.normal(mu, sigma, 5000)


z = (x_i - mu) / sigma

print("Mean (mu):", mu)
print("Standard deviation (sigma):", sigma)
print("x_i:", x_i)
print("Z-score:", z)
# Out:
# Mean (mu): 70
# Standard deviation (sigma): 3
# x_i: 77
# Z-score: 2.3333333333333335

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Sample Dataset
data = np.array([85, 90, 78, 92, 88, 76, 95, 89, 82, 80])

# Mean and Standard Deviation
mean_val = np.mean(data)
std_val = np.std(data)

print(f"Mean: {mean_val:.2f}")
print(f"Standard Deviation: {std_val:.2f}")

# Z-scores for all data points
z_scores = stats.zscore(data)
print("Z-scores:")
print(z_scores)

# Finding X from Z = 1.2
z_input1 = 1.2
x_val1 = mean_val + (z_input1 * std_val)

print(f"\nRaw score (X) for Z = 1.2: {x_val1:.2f}")

# Finding X from Z = -1.5
z_input2 = -1.5
x_val2 = mean_val + (z_input2 * std_val)

print(f"Raw score (X) for Z = -1.5: {x_val2:.2f}")

# Histogram
plt.hist(data, bins=5)
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.title("Histogram of Dataset")
plt.show()
# Out:
# Mean: 85.50
# Standard Deviation: 6.00
# Z-scores:
# [-0.08327552  0.74947971 -1.24913285  1.0825818   0.41637762 -1.58223494
#   1.58223494  0.58292866 -0.58292866 -0.91603075]
#
# Raw score (X) for Z = 1.2: 92.70
# Raw score (X) for Z = -1.5: 76.49
